# %%
import numpy as np
import pandas as pd
import jieba
import matplotlib.pyplot as plt
# from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from joblib import dump, load
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import pickle

# %%
data = pd.read_csv('dataset.csv')

# %%
data.shape
# Out:
# (32526, 3)

# %%
data.head()
# Out:
#   qid question                                          answer
# 0   1    补发网银盾  您可以到智慧柜员机办理此项业务，方便快捷，节省您的宝贵时间哦。若去柜台办理，请刷身份证取号。
# 1   2     代发工资         您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 2   3  对帐单查询打印         您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 3   4   理财产品取号                                     请说出您需要办理的业务
# 4   5     密码修改                     请您带上身份证到自助柜员机办理，简单快捷，操作容易哦。

# %%
data.loc[0, 'question']
# Out:
# '补发网银盾'

# %%
data
# Out:
#          qid question                                          answer
# 0          1    补发网银盾  您可以到智慧柜员机办理此项业务，方便快捷，节省您的宝贵时间哦。若去柜台办理，请刷身份证取号。
# 1          2     代发工资         您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 2          3  对帐单查询打印         您要办理的是对公开户、销户、签约及其他业务。请刷身份证，小龙人来帮您取个号吧。
# 3          4   理财产品取号                                     请说出您需要办理的业务
# 4          5     密码修改                     请您带上身份证到自助柜员机办理，简单快捷，操作容易哦。
# ...      ...      ...                                             ...
# 32521  69115    我要点咖啡                                        请选择您要的口味
# 32522  69116    帮忙点咖啡                                        请选择您要的口味
# 32523  69117      问题1                                              测试
# 32524  69118     1111                                          johlhk
# 32525  69119     2222                                          johlhk
#
# [32526 rows x 3 columns]

# %%
# 加载语料
with open('stopwords.txt') as file:
    stopwords = file.read().split('\n')
    
corpus = []

for question in data['question']:
    question = str(question).strip()
    corpus.append(" ".join(x for x in jieba.cut(question) if x not in stopwords))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/k2/dnh2dnfx6937855thyp78q9r0000gn/T/jieba.cache
# Loading model cost 0.844 seconds.
# Prefix dict has been built successfully.

# %%
corpus
# Out:
# ['补发 网银盾',
#  '代发 工资',
#  '帐单 查询 打印',
#  '理财产品 取号',
#  '密码 修改',
#  '查询 名下 所有 账户',
#  '交易 流水 明细 证明',
#  '个人 结售汇',
#  '现金 取款',
#  '账户 销户',
#  '转账 业务',
#  '现金 存款',
#  '贵金属 业务',
#  '个人账户 管理',
#  '开 特色 卡',
#  '吞卡 证明',
#  '补打 发票',
#  '查询 取款',
#  '本卡 转 本卡',
#  '本卡 转 现金',
#  '5 万 以内 转账',
#  '5 万 20 万 转账',
#  '20 万 200 万 转账',
#  '200 万 以上 转账',
#  '结售汇 不取 现金',
#  '结售汇 及取 现金',
#  '银星 收款',
#  '仅 查询',
#  '银星 汇款',
#  '西联 收款',
#  '西联 汇款',
#  '身份证 开卡',
#  '证件 开卡',
#  '信用卡 非现金 还款',
#  '信用卡 业务',
#  '建信 保险',
#  '保险',
#  '社保 业务',
#  '存单 业务',
#  '查询 外汇 汇率',
#  '存折 解挂',
#  '纪念币 业务',
#  '开 普通 龙卡',
#  '结算 通卡 业务',
#  '换 手机 银行 手机号',
#  '粤 通卡 充值',
#  '充值 缴费',
#  '柜台 缴费',
#  '信用卡 短信 业务',
#  '出国 惠 增值 服务',
#  '咨询 外币 旅行支票 光票 托收 业务',
#  '保费',
#  '卡折 挂失',
#  '通知 存款 转 活期 咨询',
#  '手机 银行 通知 存款 转 活期',
#  '网银 首次 购买 理财 风险 测评 提示',
#  '信用卡 挂失 生效 时间',
#  'II 类 账户 定义',
#  '手机 银行 活期 转 定期',
#  '私人 银行 客户 助业贷 扩大 抵押物 范围',
#  '外币 储蓄 利率',
#  '蓝豹 百大 龙卡 联名卡 种类',
#  '咨询 汇率 牌价',
#  '短信 推送 业务 类型 客户 反感',
#  '网银 支付 方式 适用 对象',
#  '信用卡 附属 卡开卡 条件',
#  '是否 信用卡 账单 日前 交易 都 会 反映 一期 账单 上',
#  '外币 储蓄 定期 转存',
#  '保管箱 销户',
#  '下载 个人 金交所 交易 客户端',
#  '私享品 陶瓷',
#  '查询 两年 前 交易 明细',
#  '活期存款 账户 销户',
#  '人民币 2 万 以内 取款 百元 钞',
#  '信用卡 业务',
#  '密码 重置',
#  '人民币 2 万 以上 外币 零钞 取款',
#  '自助 快存 人民币 5 万 以上 百元 钞',
#  '人民币 5 万 以内 存款 百元 钞',
#  '账户 金',
#  '基金 业务',
#  '购买 票据',
#  '柜台 存款 外币 零钞',
#  '银星 速汇',
#  '定期 支取',
#  '唯一 账户 减免 申请',
#  '睡眠 户转 正常',
#  '外汇 汇款 汇入',
#  '交收 票据',
#  '第三方 签约',
#  '资金 账户 变更',
#  '存折 开户',
#  '外汇 汇款 汇出',
#  '西联 收汇',
#  '保险业务',
#  '个人 外汇 买卖',
#  '更换 存折',
#  '个人资料 修改',
#  '资产 证明',
#  '电子 银行 关闭',
#  '手机 银行 设备 解绑',
#  '银行卡 解挂',
#  '批量 代 发卡 激活',
#  '聚财 业务',
#  '风险 评估',
#  '预约 领卡',
#  'IC卡 圈存',
#  '电子 银行 签约',
#  '卡年费 减免',
#  '智慧 柜员机 上 激活 信用卡',
#  '智慧 柜员机 上 进行 信用卡 挂失',
#  '柜员机 上 约定 信用卡 还款',
#  'ATM CRS 转账 手续费',
#  '智慧 柜员机 销户',
#  '智慧 柜员机 挂失 补卡',
#  '智慧 柜员机 开通 短信 通知',
#  '柜员机 上 办理 信用卡 账单 分期',
#  '智慧 柜员机 上 办理 现金 分期',
#  '咨询 补卡 手续费',
#  '乐 当家理财 卡 办理 条件',
#  '私人 银行 财富 贷款 自然人 联保 团体 要求',
#  '私人 银行 财富 贷款 差别化 服务',
#  '家族 信托 财务顾问 业务 介绍',
#  '财富 保 优选 项目',
#  '财富 保 优化 项目 涉及 范围',
#  '财富 传承 顾问 咨询服务 介绍',
#  '私享 久远',
#  '办理 活期存款 证明',
#  '定活两便 存款 证明',
#  '整存整取 利率 咨询',
#  'Pad   注销 手机 银行',
#  '代理 个人 金交所 业务 业务 特点',
#  '开通 个人 金交所 业务',
#  '智慧 柜员机 上 申请 信用卡',
#  '智慧 柜员机 上 信用卡 还款',
#  '个人 资信 证明 业务',
#  '开具 资信 证明 费用',
#  'POS 机 刷卡 消费 是否 收费',
#  'POS 机 办理 资料',
#  '预约 保管箱 开户',
#  '保管箱 续租',
#  '申请 保管箱 需 材料',
#  '私人 银行 出国 留学',
#  '机场 嘉宾 服务',
#  '财富 之星 价格 优惠',
#  '财富 之星 服务',
#  '私人 银行 客户 助业贷 增加 自然人 联保 方式',
#  '短信 银行 特点',
#  '短信 银行 办理 转账 汇款',
#  '咨询 短信 银行 安全性',
#  '个人 网银 注销',
#  '发短信 开通 短信 银行',
#  '结售汇 管理 要求',
#  '代理 个人 金交所 业务 交易 时间',
#  '个人账户 贵金属 业务 特点',
#  '个人账户 贵金属 交易 时间',
#  '账户 贵金属 业务 解约',
#  '个人 网银 功能',
#  '个人 网银 版本',
#  '外汇 汇率',
#  '健康 保障 险 产品 介绍',
#  '智慧 柜员机 补发 网银盾',
#  '智慧 柜员机 解绑 手机 设备',
#  '智慧 柜员机 查询 明细',
#  '智慧 柜员机 打印 明细',
#  '境内 外币 活期 转账',
#  '国泰君安 龙卡 功能',
#  '国泰君安 龙卡 申办 流程',
#  '基金 赎回',
#  '基金 定 投 方法',
#  '结算 通卡 功能',
#  '非 蓝豹 LAMPO 常州 百大 公司 会员 客户 办理 方法',
#  '出国 卡 比较 好',
#  '咨询 个人 旅行支票',
#  '电话 银行 银证 转账 流程',
#  '投资 产品 介绍',
#  '实物 贵金属 介绍',
#  '实物 贵金属 品种',
#  '账户 贵金属 产品 介绍',
#  '年 金 保险产品 介绍',
#  '个人 财险 产品 介绍',
#  '意外险 产品 介绍',
#  '财富 增值 类 保险产品 介绍',
#  '寿险 产品 介绍',
#  '电子 支付 安全 保障',
#  '网银 支付 使用 流程',
#  '账号 支付 网银 区别',
#  'PAD 银行 特点',
#  '签约 账户 与非 签约 账户',
#  '出国 攻略 出 国外 派 出国前',
#  '出国 攻略 出 国外 派 出国 中',
#  '出国 攻略 出 国外 派 回国 后',
#  '银星 国际 速汇 特点',
#  '咨询 境外 银行 分支机构',
#  '出国 适用 信用卡',
#  '信用卡 分期 手续费',
#  '信用卡 账单 最低 还款额',
#  '信用卡 产品',
#  '信用卡 预借 现金',
#  '信用卡 现金 转 出 额度',
#  '信用卡 跨行 汇款 收费',
#  '网银 支付 注销 流程',
#  '快捷 支付 注销',
#  '准 贷记卡 功能',
#  '信用卡 工本费',
#  '信用卡 取现 手续费',
#  '信用卡 透资 取现 额度',
#  '信用卡 利息 产生 途径',
#  '办理 信用卡 现金 转 出 方式',
#  '信用卡 永久 额度 调整 方式',
#  '信用卡 临时 额度 调整 方式',
#  '调低 信用卡 额度',
#  '现金 分期 申请 渠道',
#  '信用卡 账单 分期 申请 方法',
#  '信用卡 境外 取现 手续费',
#  '信用卡 境外 消费 入账 方式',
#  '现金 分期 手续费 收费 标准',
#  '购车 分期 办理 流程',
#  '信用卡 额度 调整 方式',
#  '开通 个人 网银',
#  '短信 银行 功能',
#  '网银 转账 交易 限额',
#  '信用卡 年费',
#  '信用卡 分期 收费',
#  '信用卡 账单 分期 手续费 收费 标准',
#  '咨询 挂失 补卡 时长',
#  '黄金 定 投 风险',
#  '黄金 定 投 收费',
#  '黄金 定 投 收益 计算 方式',
#  '黄金 定 投不到 期 赎回',
#  '纸黄金 风险 介绍',
#  '纸 白银 风险 介绍',
#  '账户 贵金属 收费 介绍',
#  '账户 贵金属 杠杆 情况 介绍',
#  '账户 贵金属 销户 流程',
#  '账户 贵金属 收益 计算 方式',
#  '电子式 国债',
#  '记账式 国债',
#  '凭证式 国债 购买 手续',
#  '电子式 国债 柜台 购买 流程',
#  '国债 兑付',
#  '储蓄 电子式 国债 提前 兑取',
#  '凭证式 国债 风险 介绍',
#  '乐 当家理财 卡 卡面 颜色',
#  '信用卡 办理 条件',
#  '信用卡 申请 资料',
#  '信用卡 密码 重置',
#  '信用卡 锁定 解锁',
#  '信用卡 逾期 还款',
#  '信用卡 超额 还款',
#  '无卡 还款',
#  '电话 银行 自助 购汇 还款 信用卡',
#  '网银 自助 购汇 还款',
#  '乐 当家理财 卡 是否 配套 存折',
#  '电话 银行 还款额 度 恢复',
#  '乐 当家理财 卡 金卡 白金卡 选 号 功能',
#  '人民币 购汇 还款额 度 恢复',
#  '自动 转账 还款 授权 额',
#  '商户 分期 介绍',
#  '网银 转账 还 信用卡 操作 流程',
#  'ATM 自助 转账 还 信用卡',
#  'ATM 自助 转账 还 信用卡 账 时间',
#  '拉 卡拉 还 信用卡',
#  '拉 卡拉 还 信用卡 账 时间',
#  '银联 在线 跨行 还 信用卡 账 时间',
#  '蓝豹 百大 龙卡 联名卡 有效期',
#  '蓝豹 百大 龙卡 联名卡 申请 受 地域 限制',
#  '蓝豹 百大 龙卡 联名 贵宾卡 异地 使用',
#  '蓝豹 百大 龙卡 联名卡 办理 数量 限制',
#  '龙卡 龙 卡通 定义',
#  '龙 卡通 有效期',
#  '龙 卡通 睡眠 户 激活',
#  '龙 卡通 生肖 卡',
#  '龙卡 陆港 通龙卡',
#  '陆港 通龙卡 功能',
#  '外汇 汇款',
#  '综合 账户 管理',
#  '资金 划转',
#  '日常 管家',
#  '损坏 消磁 换卡',
#  '睡眠 账户 激活',
#  '修改 开户 姓名 本人',
#  '修改 身份证 号码 本人',
#  '修改 家庭 地址 本人',
#  '修改 信息',
#  '银行卡 密码 解锁',
#  '修改 网银 绑定 手机号',
#  '修改 手机 银行 绑定 手机号',
#  '现金 增利',
#  '交易 补款',
#  '外币 储蓄 种类',
#  '查询 打印 交易 明细',
#  '挂失 有效期',
#  'ATM CRS 定期 转 活期',
#  '账号 支付 是否 需要 购买 安全 产品',
#  '快捷 支付 更改 绑定 银行账号',
#  '快捷 支付 使用 流程',
#  '电话 银行 缴 水电费',
#  '网银 支付 开通',
#  'PAD 银行 介绍',
#  'PAD 银行 功能',
#  '登录 Pad 银行',
#  'PAD 银行 是否 支持 手机 银行 网银',
#  'PAD 客户端 是否 手机 银行 客户端 是否 冲突',
#  'PAD 银行 支持 设备',
#  'ATM CRS 修改 手机号',
#  'ATM CRS 操作 帮助',
#  '解除 手机 设备',
#  'PAD 银行 账户 查询 内容',
#  '办理 活期 转 定期',
#  '客户 办理 活期存款',
#  '代办 活期存款',
#  '手机 银行 安全性 咨询',
#  '注销 PAD 银行',
#  '网银 购买 基金',
#  '网银 购买 国债',
#  '在线 网银缴 保费',
#  '在线 定期 转 活期 方法',
#  '在线 办理 零存整取',
#  '在线 申请 信用卡',
#  '信用卡 办卡 查询 进度',
#  '信用卡 密码 修改',
#  '信用卡 电话 银行 查询 密码',
#  '网银 证书 是否 过期',
#  '网上银行 定 投 黄金',
#  '农民工 银行卡 特色 服务',
#  '外币 账户 种类',
#  '保险 退保 需要 材料',
#  '基金 定 投 风险',
#  'ATM CRS 打印 明细',
#  'ATM CRS 取钱 吞卡',
#  '智慧 柜员机 换卡',
#  '智慧 柜员机 缴费',
#  '智慧 柜员机 回单 补打',
#  '智慧 柜员机 密码 重置',
#  '信用卡 挂失 补卡',
#  '咨询 境外 银行 汇款 能否 收到',
#  '零存整取 存款 证明 手续费',
#  '大额 存单 提前 支取 利息 计算',
#  'T T 汇款',
#  '手机 银行 参加 活动',
#  '手机 银行 充 游戏币',
#  '手机 银行 订 酒店',
#  '手机 银行 排号',
#  '办理 陆港 通龙卡',
#  '陆港 通龙 卡管理 费用',
#  '支付宝 龙卡 服务 特点',
#  '联名 借记卡 国泰君安 龙卡',
#  '查询 理财 交易 情况',
#  '代办 换折',
#  '换折 费用',
#  '换折 需 资料',
#  '使用 PAD 银行 收费',
#  'PAD   注销 网上银行',
#  '微信 账户 绑定 卡片 数量',
#  '微信 银行 服务 收费 问题',
#  '微信 银行 预约 服务',
#  '咨询 微信 银行 转账',
#  'Pad 开通 手机 银行',
#  '微信 银行 查询 周边 网点',
#  '柜台 开通 电话 银行',
#  '电话 银行 缴纳 过期 公共 事业费',
#  '电话 银行 转账 账户',
#  '电话 银行 查询 明细',
#  '电话 银行 人工 交易 业务',
#  '账号 支付 开通',
#  '教育 储蓄存款 优势',
#  '教育 储蓄 异地 支取',
#  '教育 储蓄 使用',
#  '通知 存款 咨询',
#  '通知 存款 办理',
#  '通知 存款 支取',
#  '通知 存款 存单 销户',
#  '通知 存款 余额 查询',
#  '教育 储蓄 开户 流程',
#  '手机 银行 修改 黄金 积存 计划',
#  '手机 银行 购买 国债',
#  '手机 银行 开 基金 账户',
#  '手机 银行 交 罚款',
#  '手机 银行 转账 手续费 咨询',
#  '手机 银行 转账 限额 咨询',
#  '手机 银行 充 话费',
#  '手机 银行 买 电影票',
#  '手机 银行 充 流量',
#  '咨询 自助 区 电话机 功能',
#  '告知 电话 自助 区 电话机 损坏',
#  '手机 银行 开 三方 存管',
#  '手机 银行 首次 风险 评估',
#  '手机 银行 风险 评估 咨询',
#  '风险 评估 有效期',
#  '手机 银行 购买 外汇 咨询',
#  '手机 银行 结汇',
#  '蓝豹 百大 龙卡 联名卡 贵宾卡 管理费用',
#  '办理 零存整取 存款 证明',
#  '零存整取 存单 销户',
#  '零存整取 到期 忘记 支取',
#  '电话 银行 信用卡 还款',
#  '电话 银行 投诉',
#  '电话 银行 好处',
#  '电话 银行 主动 服务',
#  '电话 银行 挂失',
#  '电话 银行 股票 账户 转账',
#  '进行 外汇 买卖 交易',
#  '开通 电话 银行 服务 收费',
#  '电话 银行 转账 业务',
#  '个人 电话 银行 办理 手机 话费 充值',
#  '电话 银行 办理 自助 缴费',
#  '外币 能否 存成 定期存款',
#  '个人 外汇 买卖 点 差',
#  '购买 股票 咨询',
#  '基金 定 投 介绍',
#  '基金 手续',
#  '基金 产品 类型',
#  '基金 公司',
#  '基金 评级',
#  '基金 风险',
#  '基金 手续费',
#  '货币 型基金 介绍',
#  '股票 型基金 介绍',
#  '债券 型基金 介绍',
#  '基金 定 投 手续费',
#  '基金 定 投 收益 计算 方式',
#  '基金 定 投 到期 续交',
#  '电话 银行 缴费 凭证',
#  '电话 银行 转账 限额',
#  '黄金 定 投 账户 销户 流程',
#  '电子 支付 支付 方式',
#  '网银 支付 商户 限额',
#  '网银 支付 限额',
#  '网银 登录 密码 忘记',
#  '手机 支付 使用 流程',
#  '账户 开通 快捷 支付 数量',
#  '柜面 开通 短信 银行',
#  '手机 支付 产品 支持 模式',
#  '账号 支付 限额',
#  'CRS 存 零钱',
#  'CRS 存款 限额',
#  '零存整取 续期',
#  'CRS 存 外币',
#  'CRS 电子 现金 账户 存款',
#  'ATM CRS 取 零钱',
#  'ATM CRS 取款 限额',
#  'ATM CRS 单次 取款 限额',
#  'ATM CRS 忘记 密码 取款',
#  'ATM CRS 存折 取款',
#  'ATM CRS 无卡 取款 无折 取款',
#  '代办 借记卡',
#  '结算 存折',
#  '储蓄 存折',
#  '结算 存折 储蓄 存折 区别',
#  '代办 存折',
#  '办理 存折 本人',
#  '办理 借记卡 手续费',
#  '办理 存折 手续费',
#  'I 类 账户 定义',
#  'I 类 账户 申请 开通',
#  'II 类 账户 申请 开通',
#  'III 类 账户 申请 开通',
#  '查询 账户 属于 几类 账户',
#  '办理 账户 类型 变更',
#  '网上 申请 借记卡',
#  '个人 网银 申请 借记卡',
#  '手机 银行 申请 借记卡',
#  '口头 临时 挂失',
#  '挂失 卡号 是否 更变',
#  '挂失 解冻',
#  '忘记 密码',
#  '不 挂失 后果',
#  '挂失手续 费',
#  '银行卡 销户 本人',
#  '银行卡 销户 代销',
#  '异地 销户',
#  '账号 支付 介绍',
#  '自动 转存 理财',
#  '定活两便 转 定期存款 办理',
#  '定活两便 转 活期存款 办理',
#  'ATM CRS 活期 转 定期',
#  '出国 惠 涵盖 币种',
#  '出国 惠 办理 渠道',
#  '出国 惠 优惠活动',
#  '银星 国际 速汇 概述',
#  '银星 国际 速汇 汇出 解付 业务 办理',
#  '银星 国际 速汇 服务 对象',
#  '银星 国际 速汇 收费 标准',
#  '境外 银行 联系方式',
#  '出国 留学 准备',
#  '境外 投资',
#  '存折 销户 本人',
#  '网上 自助 销户',
#  '信用卡 附属 卡开卡 资料',
#  '代办 激活 信用卡 咨询',
#  '不 销户 影响',
#  '借记卡 销户 手续费',
#  '办理 零存整取 提前 支取',
#  'PAD 安全性 保障',
#  '使用 PAD 银行 注意事项',
#  '签约 账户 是否 转账',
#  'PAD 银行 交易 限额',
#  'PAD 银行 转账 手续费',
#  'PAD 转账 账 时间',
#  'PAD 网银端 转账',
#  'PAD 银行 看不到 定期存款',
#  'PAD 银行 查询 账户 类型',
#  'PAD 银行 查看 活期 资产 趋势 图',
#  'PAD 查询 明细 错误 提示',
#  'PAD 银行 购买 理财 业务',
#  'PAD 银行 风险 评估',
#  'PAD 银行 上 售 理财 网银 理财 展示 不 一致',
#  'PAD 银行 办理 信用卡 业务 功能',
#  'PAD 银行 信用卡 还款 查询',
#  'PAD 银行 还 信用卡',
#  'PAD 银行 代 还 信用卡',
#  'PAD 银行 中 悦 生活',
#  'PAD 银行 悦 生活 缴费',
#  '准 贷记卡 种类',
#  '乐 当家理财 卡 领卡 时间',
#  '乐 当家理财 卡 支持 存款 类型',
#  '乐 当家理财 卡 到期 换卡',
#  '个人 网银 预约 挂号',
#  '预约 取款',
#  '公积金 联名卡 年费',
#  '网点 业务 预约',
#  '手机 银行 办理 业务 预约',
#  '个人 网银 办理 业务 预约',
#  '操作 境内 转账 境外 银行',
#  '咨询 是否 能购 外汇 现钞',
#  '咨询 购 外汇 现钞',
#  '咨询 留学 资产 证明 要求',
#  '咨询 留学签证 资金 要求',
#  '自动 转存 介绍',
#  '自动 转存 办理',
#  '自动 转存 利息',
#  '个人 通知 存款 自动 转存',
#  '定期存款 自动 转存 定义',
#  '自动 转存 收益',
#  '自动 转存 提前 支取',
#  '代办 自动 转存 提前 支取',
#  '自动 转存 起存 金额',
#  '自动 转存 优势',
#  '自动 转存 提前 支取 收益',
#  '外币 储蓄 介绍',
#  '外币 储蓄 办理',
#  '外币 储蓄 销户',
#  '外币 储蓄 收益',
#  '外币 储蓄 理财',
#  '外币 储蓄 提前 支取',
#  '外币 储蓄 起存 金额',
#  '外币 手机 银行 进行 转账',
#  '补卡 换卡 能否 保留 原 卡号',
#  '打印 两年 前 交易 明细',
#  '查询 理财产品 持有 情况',
#  '咨询 出国 金融服务',
#  '咨询 能否 办理 签证 服务',
#  '办理 存款 证明',
#  '留学 贷款 服务',
#  '留学 贷款 作用',
#  '境外 汇票',
#  '咨询 是否 外汇业务',
#  '办理 外汇 汇票',
#  '咨询 购汇 金额 限制',
#  '微信 银行 功能',
#  '基金 定 投 到期 赎回',
#  '基金 账户 销户 流程',
#  '实物 贵金属 购买 手续',
#  '实物 贵金属 提货',
#  '实物 贵金属 回购',
#  '实物 贵金属 退货',
#  '贵金属 存放',
#  '个人 网银 查询 网点 业务 预约 信息',
#  '查询 银行 联行 号',
#  '私人 银行卡 申办 条件',
#  '健康 关爱',
#  '国际 紧急 援助',
#  '机场 礼宾 车 服务',
#  '养老 规划',
#  '信用 尊享',
#  '财富 之星 额度 倾斜',
#  '财富 贷',
#  '私人 银行 客户 助业贷',
#  '挂失 补卡',
#  '手机 银行 办理 信用卡 手续',
#  '手机 银行 申办 信用卡 额度',
#  '手机 银行 解锁 信用卡',
#  '手机 银行 查询 信用卡 初始密码',
#  '手机 银行 查询 信用卡 邮寄 情况',
#  '短信 银行 服务费',
#  '短信 银行 交易 结算 费',
#  '短信 银行 注销',
#  '短信 提示 无法 正常 接收',
#  '短信 提醒 错发',
#  '短信 服务 提醒 门槛',
#  '网上银行 开通 短信 银行',
#  '个人账户 贵金属 业务 品种',
#  '个人账户 贵金属 定 投 业务 介绍',
#  '个人账户 贵金属 定 投 业务 投 金额',
#  '个人账户 贵金属 定 投 业务 定 投 周期',
#  '个人账户 贵金属 定 投 业务 定 投 起始 日',
#  '修改 撤销 账户 贵金属 定 投',
#  '账户 贵金属 定 投 业务 办理 渠道',
#  '个人 网银 开通 资费',
#  '购车 分期 介绍',
#  '信用卡 额度 恢复',
#  '挂失 信用卡 后 重新 找到 后 能否 重新 使用',
#  '万事达卡 境外 遗失',
#  '首次 登录 个人 网银 密码 设置',
#  '个人 网银 登录 密码 重置',
#  '查询 网银 交易 明细',
#  '调整 网银 交易 限额',
#  '网银缴 水电费',
#  '网银缴 话费',
#  '网银缴 有线电视 费',
#  '设置 网银 登录 预留 信息',
#  '网银 登录 验证码 提示 错误',
#  '网银 登录 不 上去',
#  '网银 登录 用户名 已 存在 提示',
#  '信用卡 账单 分期 促销 活动',
#  '消费 分期 促销 活动',
#  '商户 分期 促销 活动',
#  '信用卡 账单 分期 办理 条件',
#  '消费 分期 介绍',
#  '购车 分期 好处',
#  '商户 分期 好处',
#  '消费 分期 适用 条件',
#  '购车 分期 合作 品牌',
#  '办理 信用卡 分期',
#  '信用卡 分期 后 信用 额度 变化',
#  '信用卡 分期 提前 还款',
#  '信用卡 账单 分期 期数',
#  '信用卡 消费 分期 期数',
#  '无卡 交易 失败 咨询',
#  '账单 咨询',
#  '信用卡 交易 失败 咨询',
#  '预 授权 咨询',
#  '风险 咨询',
#  '外币 卡 咨询',
#  '境外 信用卡 类型',
#  '咨询 VISA卡',
#  '咨询 万事达卡',
#  '咨询 银联 单 币种 卡',
#  'VISA卡 使用',
#  '万事达卡 使用',
#  '信用卡 国外 取 现金额 限制',
#  'VISA卡 万事达卡 区别',
#  '手机 银行 转账 不 成功',
#  '更改 预留 手机号',
#  '做',
#  '借记卡 开户',
#  '推荐 信用卡',
#  '吃 早饭',
#  '约定 还款',
#  '未成年人 开户',
#  '今年 多少岁',
#  '非常感谢',
#  '取号 需要 证件',
#  '银行卡 开户',
#  '保险产品 犹豫 期',
#  '自助 设备 上 转账',
#  '最 喜欢 金总唱 首歌',
#  '房屋 装修 能否 提取 住房 公积金',
#  '借记卡 激活',
#  '短信 通知 余额 提醒',
#  '开户 需要 证件',
#  '申请 信用卡 临时 额度',
#  '有效 身份证件',
#  '临时 身份证 开户',
#  '理财产品 到期 取',
#  '信用卡 境内 消费 手续费',
#  '退休 人员 提取 公积金 需要 材料',
#  '信用卡 还款',
#  '信用卡 到期 换卡 密码',
#  '一段 freestyle',
#  '自助 设备 办理 跨行 转账 账 时间',
#  '银行 代销 产品',
#  '遗忘 住房 公积金 联名卡 密码',
#  '住房 公积金 缴存 情况',
#  '申请 贵宾卡 多久 取卡',
#  '转账 时 收款 账户 信息 有误 转错 人 处理',
#  '借记卡 境外 取款 手续费',
#  '查询 个人 网银 办理 转账 记录',
#  '手机 银行 进行 缴费 充值',
#  '利率 表现形式 换算',
#  '约定 还款 余额 不足',
#  '储蓄卡 挂失 后 解除 挂失',
#  '登录 手机 银行 客户端 时 获取 授权 码',
#  '个人 网银 办理 跨行 转账 时 无法 选择 他行 开户行 网点',
#  '龙卡云 闪付 支付 适用 系统 手机',
#  '龙卡云 闪付 借记卡 交易 限额',
#  '查询 征信 记录',
#  '第三方 支付 平台 办理 提现 退款 转账 账 时间 多久',
#  '已经 柜台 签约 个人 网银 需要 添加 本人 名下 账户 用于 转账 汇款 类 操作 办理',
#  '本人 名下 储蓄 账户 柜台 开通 个人 网银 账户 换卡',
#  '网银盾 丢失 处理',
#  '未 按时 归还 个人 贷款 会 影响',
#  '信用卡 电话',
#  '已经 还 贷款 还 收到 提示 还款 短信',
#  '龙卡云 闪付 使用 手机 进行 移动 支付 交易',
#  '提前 还贷',
#  '个人 网银 用户名 遗忘',
#  '解绑 手机 银行 客户端 原 手机 无法 使用',
#  '万事达卡 收费 问题',
#  '外币 信用卡 还款 方式',
#  '个人 网银 归还 信用卡 外币 欠款',
#  'VISA卡 境外 遗失',
#  '停用 信用卡',
#  '打印 信用卡 明细',
#  '信用卡 刷卡 消费 注意事项',
#  '信用卡 境外 消费 注意事项',
#  '银联 在线 跨行 还 信用卡',
#  '信用卡 邮寄 情况',
#  '信用卡 还款 利息 试算',
#  '手机 银行 外汇 转账',
#  '询问 信用卡 额度 是否 固定',
#  '手机 银行 外汇 转账 限额 限制',
#  '手机 银行 挂失',
#  '手机 银行 修改 预留 手机号',
#  '手机 银行 预留 信息 修改',
#  '手机 银行 注销',
#  '咨询 自助 区 电话 银行 能否 拨打 客服',
#  'ATM CRS 存钱 卡钞',
#  '消费 分期 好处',
#  '补发 网银盾 业务',
#  '个人 存款 证明 定义',
#  '教育 储蓄 存款 期限',
#  '教育 储蓄 利息',
#  '教育 储蓄 存款 限额',
#  'ATM CRS 手机 预约 取款',
#  'ATM CRS 刷 脸 取款',
#  'ATM CRS 异地 卡 取款',
#  'ATM CRS 取 外币',
#  'ATM CRS 电子 现金 账户 取款',
#  '储蓄卡 长期 不 使用 是否 影响 信用 记录',
#  '挂失 补卡后 签约 关系 是否 会 改变',
#  '补缴 短信 银行 服务费',
#  '贷款 扣款 日 扣款 失败',
#  '龙卡云 闪付 支付 账户 类型',
#  '有没有 美元',
#  '缴 交通 罚款',
#  '信用卡 还款 小贴士',
#  '电话 银行 办理 定期 活期 之间 转账',
#  '认识 金总',
#  '信用卡 资料 修改',
#  '手机 无法 接受 短信 验证码',
#  '认识',
#  '手机 银行 登录 密码 遗忘 锁定 处理',
#  '手机 手机 转账',
#  '说 英语',
#  '公积金 贷款 首付 比例',
#  '办理 约定 还款',
#  '银联 缴费',
#  '未 号',
#  '手机 银行 办理 特约 取款',
#  'ATM CRS 忘记 密码 转账',
#  'ATM CRS 无卡 转账 无折 转账',
#  'ATM CRS 行卡 转账',
#  'ATM CRS 现金 汇款',
#  'ATM CRS 跨行 转账',
#  'ATM CRS 撤销 转账',
#  '蓝豹 百大 龙卡 联名卡 有无 附属 卡',
#  'ATM CRS 从卡 转到 电子 现金 账户',
#  'ATM CRS 人民币 转 外币 账户',
#  'ATM CRS 查询 余额',
#  'ATM CRS 修改 密码',
#  'ATM CRS 还 信用卡',
#  'ATM CRS 查询 信用卡 账单',
#  'ATM CRS 还 信用卡 账 时间',
#  'ATM CRS 存折 打印',
#  'ATM CRS 取款 收到 两次 短信 扣款',
#  'ATM CRS 存款 账户 余额 没 变',
#  '身份证 异常 开户',
#  '证件 开户',
#  '办理 公积金',
#  '合照',
#  '手机 银行 取消 储蓄 账户 资金 变动 短信 通知 服务',
#  '95533 取消 储蓄 账户 资金 变动 短信 通知 服务',
#  '龙卡云 闪付 功能',
#  '个人 网银 取消 储蓄 账户 资金 变动 短信 通知 服务',
#  '柜台 办理 个人 网银 签约 后 激活',
#  '储蓄卡 账户 管理费',
#  '不去 地点',
#  '会 走路',
#  '开 存折 收费',
#  '信用卡 丢失',
#  '贷款 利率 查询',
#  '信用卡 现金 分期 手续费',
#  '定期 利率 查询',
#  '电子式 国债 风险 介绍',
#  '智慧 柜员机 修改 密码',
#  '记账式 国债 风险 介绍',
#  '国债 手续费 介绍',
#  '国债 收益 介绍',
#  '凭证式 国债 计息 规则',
#  '理财产品 风险',
#  '理财产品 购买 条件',
#  '理财产品 投资 期限',
#  '理财 提前 支取',
#  '理财产品 收益',
#  '理财产品 手续费',
#  '理财产品 起售 门槛',
#  'ATM CRS 转账 输错 账号',
#  'CRS 定义',
#  'ATM 定义',
#  '智慧 柜员机 开户',
#  '智慧 柜员机 代办 开户',
#  '智慧 柜员机 办 存折',
#  '智慧 柜员机 办 存单',
#  '智慧 柜员机 上 修改 密码',
#  '手机 银行 功能',
#  '手机 银行 查询 功能',
#  '手机 银行 零存整取',
#  '手机 银行 通知 存款 办理',
#  '手机 银行 购买 账户 贵金属',
#  '手机 银行 签约 账户 贵金属',
#  '手机 银行 购买 黄金',
#  '手机 银行 定 投 黄金',
#  '咨询 代 销户 零存整取 账户',
#  '智慧 柜员机 上 代办 修改 密码',
#  '智慧 柜员机 代办 补卡',
#  '智慧 柜员机 补办 存折',
#  '智慧 柜员机 补办 存单',
#  '智慧 柜员机 开通 手机 银行',
#  '智慧 柜员机 代办 开通 手机 银行',
#  '智慧 柜员机 代 开通 短信 通知',
#  '智慧 柜员机 上 修改 手机号',
#  '智慧 柜员机 上 代办 更换 手机号',
#  '智慧 柜员机 上 修改 转账 限额',
#  '智慧 柜员机 上 代办 修改 转账 限额',
#  '智慧 柜员机 查看 汇率',
#  '智慧 柜员机 存折 补登',
#  '智慧 柜员机 上 缴纳 交通 罚款',
#  '理财产品 风险 评估 有效期 多久',
#  '保险类别',
#  '保险公司',
#  '保险 缴费 方法',
#  '保险 申请 流程',
#  '信用卡 挂失 方法',
#  '信用卡 挂失 补卡 方法',
#  '挂失 信用卡 费用',
#  '信用卡 分期 提前 还款 手续费',
#  'VISA卡 收费 问题',
#  '手机 银行 归还 信用卡 外币 欠款',
#  '代销 活期存款 账户',
#  '定活两便 产品 介绍',
#  '定活两便 利率',
#  '汇款 还 信用卡',
#  '信用卡 收费 项目 查询',
#  '信用卡 未激活 会 收费',
#  '信用卡 超限 费 收取',
#  '信用卡 取现',
#  '信用卡 国外 取现',
#  '信用卡 代扣 业务',
#  '信用卡 固定 额度 临时 额度',
#  '信用卡 拒 原因',
#  '信用卡 积分 实效性',
#  '信用卡 积分 兑换 情况 查询',
#  '信用卡 挂失 后 安全性',
#  '补办 信用卡 领卡 时长',
#  '信用卡 销户 后 账户 余额 处理',
#  '支付宝 还 信用卡 账 时间',
#  '信用卡 销户 办理 方式',
#  '信用卡 附属 卡 挂失',
#  '补办 信用卡 卡号 是否 会 改变',
#  '现金 分期 办理 要求',
#  '现金 分期 业务 亮点',
#  '现金 分期 促销 活动',
#  '信用卡 账单 分期 业务 介绍',
#  '信用卡 账单 分期 优势',
#  '定活两便 销户',
#  '外币 定活两便 存款',
#  '定活两便 挂失',
#  '定活两便 相对 存款 优势 特点',
#  '定活两便 通存通兑',
#  '咨询 活期存款 利息',
#  '智慧 柜员机 上查 违章 扣分',
#  '智慧 柜员机 上 支取 定期',
#  '是否 智慧 柜员机 上 进行 贵金属 买卖',
#  '智慧 柜员机 上 查询 贵金属 购买 情况',
#  '智慧 柜员机 购买 理财',
#  '智慧 柜员机 查询 理财 交易',
#  '智慧 柜员机 上 撤销 购买 理财产品',
#  '智慧 柜员机 上 赎回 理财产品',
#  '信用卡 积分 定义',
#  '金 管家 个人 客户 家庭 现金管理 服务',
#  '财富 传承 顾问 咨询服务 职责',
#  '私人 银行 客户 信用 贷',
#  '手机 银行 购买 证券',
#  '手机 银行 买 火车票',
#  '微信 银行 查询 账户 余额 账单 明细',
#  '微信 银行 信用卡 还款',
#  '微信 银行 买 理财',
#  '微信 银行 在线 贷款',
#  '境外 ATM 查询 手续费',
#  '智慧 柜员机 上 查询 定期',
#  '智慧 柜员机 上 查询 基金 交易 情况',
#  '财富 之星 介绍',
#  '国际 速汇',
#  '个人 结售汇 定义',
#  '个人 结售汇 办理',
#  '电子 渠道 办理 个人 结售汇',
#  '手机 银行 预约 兑换 零钱',
#  '手机 丢失',
#  '手机 银行 申请 贷款',
#  '信用卡 积分 兑换',
#  '个人 资信 证明 时段 期限',
#  '办理 资信 证明 需 资料',
#  '资信 证明 能否 代办',
#  '定活两便 办理 流程',
#  'POS 机 办理 方式',
#  '整存整取 业务 咨询',
#  '整存整取 办理',
#  '存单 挂失 咨询',
#  '咨询 提前 支取',
#  '咨询 自动 转存',
#  '办 存款 证明',
#  '定期 未 到期 销户',
#  '定期 到期 支取',
#  '办理 零存整取',
#  '咨询 零存整取 存期',
#  '账户 综合 电子 账单',
#  '零存整取 优点',
#  '定活两便 起存 金额',
#  '定活两便 转 办理 理财 业务',
#  '个人 外汇 代办',
#  '零存整取 是否 提前 支取',
#  '大额 存单 质押 贷款 办理 流程',
#  '外币 兑换',
#  '旅行支票 介绍',
#  '外币 票据 托收',
#  '现金 分期 业务 介绍',
#  '外汇 期权 办理',
#  '外汇 汇款 分类',
#  '专款 预留',
#  '开立 外币 账户',
#  '外币 储蓄 计息 方式',
#  '陆港 通龙卡 申办 资格',
#  '修改 取款 密码',
#  '存折 销户 代销',
#  '电话 银行 客服 电话',
#  'Pad 开通 网上银行',
#  '非 第一次 购买 理财',
#  '手机 银行贷款 查询',
#  '手机 银行 查询 信用卡 信息',
#  '手机 银行 能否 购买 保险',
#  '手机 银行 能否 购买 基金',
#  '短信 银行 介绍',
#  '短信 提醒 非官方 号码',
#  '手机 银行 购买 理财',
#  '网银 在线 办理 结售汇',
#  '网银 证书 使用 期限',
#  '网银 网上银行 购买 理财',
#  '手机 银行 信用卡 额度 查询',
#  '网银 购买 证券',
#  '在线 活期 转 定期',
#  '在线 定期 转 活期',
#  '在线 账户 挂失',
#  '开通 手机 银行 收费',
#  '手机 银行 开通 条件',
#  '设置 信用卡 密码',
#  '修改 信用卡 密码',
#  '信用卡 免息 还款',
#  '手机 银行 开通 短信 银行',
#  '基金 定义',
#  '代理 个人 金交所 业务 业务 定义',
#  'POS 机 功能 介绍',
#  'POS 机 押金',
#  'POS 机 故障',
#  'POS 机 支持 刷 外币',
#  'POS 机 挂失',
#  '代 缴费 自助 缴费 业务 类型',
#  '代 缴费 自助 缴费 办理 渠道',
#  '办理 鑫 存管',
#  '变更 鑫 存管 签约 账户',
#  '撤销 鑫 存管 签约 账户',
#  '鑫 存管 签约 账户 信息 变更',
#  '鑫 存管 收费 情况',
#  '保管箱 收费',
#  '保管箱 押金',
#  '保管箱 业务 介绍',
#  '保管箱 开箱',
#  '保管箱 授权 开箱 问题',
#  '保管箱 钥匙 遗失 问题',
#  '大额 存单 产品 介绍',
#  '大额 存单 购买 需 手续',
#  '大额 存单 利率 咨询',
#  '大额 存单 能否 提前 支取',
#  '大额 存单 支取',
#  '咨询 大额 存单 资信 证明 能否 办理',
#  '大额 存单 资信 证明 办理 流程',
#  '咨询 大额 存单 质押 贷款 能否 办理',
#  '大额 存单 冻结',
#  '大额 存单 转让',
#  '大额 存单 挂失',
#  '大额 存单 转 活期',
#  '大额 存单 起购 金额',
#  'PAD 银行 账户 查询 操作',
#  '私人 银行 用途',
#  'III 类 账户 定义',
#  '忘记 密码 能否 CRS 上 存款',
#  'CRS 无折 无卡 存款',
#  'CRS 行卡 存款',
#  'CRS 单次 存款 限额',
#  ...]

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf = tfidf_vectorizer.fit_transform(corpus)
kmeans = KMeans(n_clusters=200).fit(tfidf)


# 打印出各个类的中心点
# print(kmeans.cluster_centers_)
# for index, label in enumerate(kmeans.labels_, 1):
#     print("index: {}, label: {}".format(index, label))

# 样本距其最近的聚类中心的平方距离之和inertia_，用来评估分类的准确度，值越小越好
# 调整超参数n_clusters可以改善inertia_
print("inertia: {}".format(kmeans.inertia_))

dump(kmeans, 'kmeans_200.joblib')
# Out:
# inertia: 24738.84776659175
# ['kmeans_200.joblib']

# %%
dump(tfidf_vectorizer, 'tfidf_vectorizer_200.joblib')
# Out:
# ['tfidf_vectorizer_200.joblib']

# %%
kmeans = load('kmeans_200.joblib')

# %%
tfidf_vectorizer = load('tfidf_vectorizer_200.joblib')

# %%
user_input = ['补发 网银盾']
result = kmeans.predict(tfidf_vectorizer.transform(user_input))

# %%
result[0]
# Out:
# 4
